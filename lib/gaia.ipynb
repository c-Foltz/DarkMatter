# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
# from astroquery.gaia import Gaia

from astropy.constants import M_sun, L_sun

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %%
hr = 3*u.kpc

L_sun=1
M_sun=1

L_15=1.8e10*L_sun
M_15=6e10*M_sun

M_L_disk=M_15/L_15

L_15_wo_factor=np.exp(-25/2.25)*np.pi*(25)**2*L_sun
a=L_15/L_15_wo_factor

# %%
def L(R):
    return(a*np.exp(-R/3)*np.pi*R**2)

# %%
def M(R):
    return(L(R)*M_L_disk)

# %%
x=np.arange(0.01,25,0.01)
y=M(x)
plt.plot(x,y)

# %%
M_L_disk
# Out:
# 3.3333333333333335

# %%
z_thin=0.35
hr=2.25
z_const=0.67

# %%
def M_disk(R):
    return(z_const*0.05e12*(-hr)*(np.exp(-R/hr)-1))

# %%
plt.plot(x,M_disk(x))

# %%
m_bulge=1.0e10
R_bulge=4

# %%
def M_bulge(R):
    if R<=4:
        return (R/R_bulge)**3*m_bulge
    else:
        return m_bulge

# %%
def mass(R):
    return(M_disk(R)+vec_M_bulge(R))

# %%
x=np.arange(0.1,30,0.01)
plt.plot(x,mass(x))

# %%
mass(25)
# Out:
# 85373873495.10872

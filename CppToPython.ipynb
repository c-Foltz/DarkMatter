# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefix = "./data/GS4_Trace"
dataType=["_rXV.txt","_rYT.txt","_xxerror.txt","_yTerror.txt"]
noArray=np.concatenate([np.arange(1,279),np.arange(328,360)])

# %%
x=np.loadtxt(prefix+"1"+dataType[0])
y=np.loadtxt(prefix+"1"+dataType[1])
xError=np.loadtxt(prefix+"1"+dataType[2])
yError=np.loadtxt(prefix+"1"+dataType[3])

# %%
plt.errorbar(x,y,xerr=xError,yerr=yError)
plt.show()

# %%
pwd
# Out:
# '/Users/user/.Trash/darkMatter'
